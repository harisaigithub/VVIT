# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\kgnan\\OneDrive\\Desktop\\ANN\\pandas\\concrete.csv")
#data frame is basically rows and columns of data.

# %%
df
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
#single feature scaling
df['age']=df['age']/df['age'].max()

# %%
df.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg       age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5  0.076712
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2  0.038356
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2  0.076712
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0  0.076712
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7  0.076712
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
#MinMax
df['water']=(df['water']-df['age'].min())/(df['water'].max()-df['age'].min())

# %%
df.head()
# Out:
#    cement   slag    ash     water  superplastic  coarseagg  fineagg       age  \
# 0   141.3  212.0    0.0  0.823885           0.0      971.8    748.5  0.076712
# 1   168.9   42.2  124.3  0.640887          10.8     1080.8    796.2  0.038356
# 2   250.0    0.0   95.7  0.758702           5.5      956.9    861.2  0.076712
# 3   266.0  114.0    0.0  0.923076           0.0      932.0    670.0  0.076712
# 4   154.8  183.4    0.0  0.782589           9.1     1047.4    696.7  0.076712
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
#z-score
df['slag']=(df['slag']-df['slag'].mean())/df['slag'].std()

# %%
df.head()
# Out:
#    cement      slag    ash     water  superplastic  coarseagg  fineagg  \
# 0   141.3  1.600663    0.0  0.823885           0.0      971.8    748.5
# 1   168.9 -0.367363  124.3  0.640887          10.8     1080.8    796.2
# 2   250.0 -0.856472   95.7  0.758702           5.5      956.9    861.2
# 3   266.0  0.464818    0.0  0.923076           0.0      932.0    670.0
# 4   154.8  1.269182    0.0  0.782589           9.1     1047.4    696.7
#
#         age  strength
# 0  0.076712     29.89
# 1  0.038356     23.51
# 2  0.076712     29.22
# 3  0.076712     45.85
# 4  0.076712     18.29

# %%
import numpy as np
df['cement']=np.log(df['cement'])

# %%
df.head()
# Out:
#      cement      slag    ash     water  superplastic  coarseagg  fineagg  \
# 0  4.950885  1.600663    0.0  0.823885           0.0      971.8    748.5
# 1  5.129307 -0.367363  124.3  0.640887          10.8     1080.8    796.2
# 2  5.521461 -0.856472   95.7  0.758702           5.5      956.9    861.2
# 3  5.583496  0.464818    0.0  0.923076           0.0      932.0    670.0
# 4  5.042134  1.269182    0.0  0.782589           9.1     1047.4    696.7
#
#         age  strength
# 0  0.076712     29.89
# 1  0.038356     23.51
# 2  0.076712     29.22
# 3  0.076712     45.85
# 4  0.076712     18.29

# %%
from scipy.stats import zscore
df['fineagg']=zscore(df['fineagg'])

# %%
df.head()
# Out:
#      cement      slag    ash     water  superplastic  coarseagg   fineagg  \
# 0 -1.621636  1.600663    0.0  0.823885           0.0      971.8 -0.312970
# 1 -1.153050 -0.367363  124.3  0.640887          10.8     1080.8  0.282260
# 2 -0.123143 -0.856472   95.7  0.758702           5.5      956.9  1.093371
# 3  0.039780  0.464818    0.0  0.923076           0.0      932.0 -1.292542
# 4 -1.381991  1.269182    0.0  0.782589           9.1     1047.4 -0.959363
#
#         age  strength
# 0  0.076712     29.89
# 1  0.038356     23.51
# 2  0.076712     29.22
# 3  0.076712     45.85
# 4  0.076712     18.29

# %%
from scipy.stats import zmap
df['ash']=zmap(df['ash'], df['superplastic'])

# %%
df.head()
# Out:
#      cement      slag        ash     water  superplastic  coarseagg   fineagg  \
# 0 -1.621636  1.600663  -1.039143  0.823885           0.0      971.8 -0.312970
# 1 -1.153050 -0.367363  19.778347  0.640887          10.8     1080.8  0.282260
# 2 -0.123143 -0.856472  14.988482  0.758702           5.5      956.9  1.093371
# 3  0.039780  0.464818  -1.039143  0.923076           0.0      932.0 -1.292542
# 4 -1.381991  1.269182  -1.039143  0.782589           9.1     1047.4 -0.959363
#
#         age  strength
# 0  0.076712     29.89
# 1  0.038356     23.51
# 2  0.076712     29.22
# 3  0.076712     45.85
# 4  0.076712     18.29
