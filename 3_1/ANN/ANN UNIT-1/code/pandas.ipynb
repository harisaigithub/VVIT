# %%
# Creating empty series
import pandas as pd
ser = pd.Series([1,3,4,5,6])


print(ser)
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\kgnan\\OneDrive\\Desktop\\ANN\\pandas\\student_marks.csv")
#data frame is basically rows and columns of data.

# %%
print(df)
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78     NaN      91    91.0      88      98      94
# 1        22001      79    71.0      81    72.0      73      68      59
# 2        22002      66    65.0      70    74.0      78      86      87
# 3        22003      60     NaN      54     NaN      54      57      64
# 4        22004      99    95.0      96    93.0      97      89      92
# 5        22005      41    36.0      35    28.0      35      36      27
# 6        22006      47    50.0      47    57.0      62      64      71
# 7        22007      84    74.0      70    68.0      58      59      56
# 8        22008      74    64.0      58    57.0      53      51      47
# 9        22009      87    81.0      73    74.0      71      63      53
# 10       22010      40    34.0      37    33.0      31      35      39
# 11       22011      91    84.0      78    74.0      76      80      80
# ...

# %%
df.shape
# Out:
# (56, 13)

# %%
pd.set_option('display.max_columns',13)

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78     NaN      91    91.0      88      98      94
# 1        22001      79    71.0      81    72.0      73      68      59
# 2        22002      66    65.0      70    74.0      78      86      87
# 3        22003      60     NaN      54     NaN      54      57      64
# 4        22004      99    95.0      96    93.0      97      89      92
# 5        22005      41    36.0      35    28.0      35      36      27
# 6        22006      47    50.0      47    57.0      62      64      71
# 7        22007      84    74.0      70    68.0      58      59      56
# 8        22008      74    64.0      58    57.0      53      51      47
# 9        22009      87    81.0      73    74.0      71      63      53
# 10       22010      40    34.0      37    33.0      31      35      39
# 11       22011      91    84.0      78    74.0      76      80      80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  56 non-null     int64
#  1   Test_1      56 non-null     int64
#  2   Test_2      54 non-null     float64
#  3   Test_3      56 non-null     int64
#  4   Test_4      55 non-null     float64
#  5   Test_5      56 non-null     int64
#  6   Test_6      56 non-null     int64
#  7   Test_7      56 non-null     int64
#  8   Test_8      56 non-null     int64
#  9   Test_9      56 non-null     int64
#  10  Test_10     56 non-null     int64
#  11  Test_11     56 non-null     int64
#  12  Test_12     56 non-null     int64
# dtypes: float64(2), int64(11)
# memory usage: 5.8 KB

# %%
# print first 5 rows from the data frame
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1172c923ce43> in <module>
#       1 # print first 5 rows from the data frame
# ----> 2 df.head(10)
#
# NameError: name 'df' is not defined

# %%
#print last 5 rows of the table
df.tail()
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 51       22051      70    60.0      70    62.0      67      67      68
# 52       22052      63    73.0      70    63.0      60      67      61
# 53       22053      92   100.0     100   100.0     100     100      92
# 54       22054      64    55.0      54    61.0      63      57      47
# 55       22055      60    66.0      68    58.0      49      47      39
#
#     Test_8  Test_9  Test_10  Test_11  Test_12
# 51      67      72       69       64       65
# 52      59      52       58       56       46
# 53      87      94      100       94       98
# 54      37      44       48       54       54
# 55      29      39       44       39       45

# %%
#dealing with columns.
#1 using dot(.) 
#df.Test_2
#2.using []
df["Test_1"]
# Out:
# 0      78
# 1      79
# 2      66
# 3      60
# 4      99
# 5      41
# 6      47
# 7      84
# 8      74
# 9      87
# 10     40
# 11     91
# 12     81
# 13     52
# 14     63
# 15     76
# 16     83
# 17     55
# 18     71
# 19     62
# 20     44
# 21     50
# 22     57
# 23     59
# 24     84
# 25     74
# 26     92
# 27     63
# 28     78
# 29     55
# 30     54
# 31     84
# 32     95
# 33     64
# 34     76
# 35     78
# 36     95
# 37     99
# 38     82
# 39     65
# 40    100
# 41     78
# 42     98
# 43     58
# 44     96
# 45     86
# 46     48
# 47     56
# 48     42
# 49     64
# 50     50
# 51     70
# 52     63
# 53     92
# 54     64
# 55     60
# Name: Test_1, dtype: int64

# %%
#accessing multiple columns
df[["Test_1","Test_6"]]
# Out:
#     Test_1  Test_6
# 0       78    98.0
# 1       79     NaN
# 2       66    86.0
# 3       60    57.0
# 4       99    89.0
# 5       41    36.0
# 6       47    64.0
# 7       84    59.0
# 8       74    51.0
# 9       87    63.0
# 10      40    35.0
# 11      91    80.0
# 12      81    90.0
# 13      52    30.0
# 14      63    86.0
# 15      76    76.0
# 16      83    72.0
# 17      55    35.0
# 18      71    61.0
# 19      62    59.0
# 20      44    34.0
# 21      50    38.0
# 22      57    36.0
# 23      59    40.0
# 24      84    80.0
# 25      74   100.0
# 26      92    83.0
# 27      63    55.0
# 28      78    74.0
# 29      55    62.0
# 30      54    45.0
# 31      84    95.0
# 32      95    99.0
# 33      64    68.0
# 34      76    86.0
# 35      78    48.0
# 36      95    94.0
# 37      99    81.0
# 38      82    80.0
# 39      65    51.0
# 40     100    76.0
# 41      78    73.0
# 42      98    92.0
# 43      58    63.0
# 44      96    95.0
# 45      86    91.0
# ...

# %%
# to know column names
df.columns
# Out:
# Index(['Student_ID', 'Test_1', 'Test_2', 'Test_3', 'Test_4', 'Test_5',
#        'Test_6', 'Test_7', 'Test_8', 'Test_9', 'Test_10', 'Test_11',
#        'Test_12'],
#       dtype='object')

# %%
df.head()
# Out:
#    Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  \
# 0       22000      78     NaN      91    91.0      88      98      94     100
# 1       22001      79    71.0      81    72.0      73      68      59      69
# 2       22002      66    65.0      70    74.0      78      86      87      96
# 3       22003      60     NaN      54     NaN      54      57      64      62
# 4       22004      99    95.0      96    93.0      97      89      92      98
#
#    Test_9  Test_10  Test_11  Test_12
# 0     100      100      100       93
# 1      59       60       61       67
# 2      88       82       90       86
# 3      72       63       72       76
# 4      91       98       95       88

# %%
#dealing with rows 1.loc 2.iloc
df.iloc[0]
# Out:
# Student_ID    22000.0
# Test_1           78.0
# Test_2            NaN
# Test_3           91.0
# Test_4           91.0
# Test_5           88.0
# Test_6           98.0
# Test_7           94.0
# Test_8          100.0
# Test_9          100.0
# Test_10         100.0
# Test_11         100.0
# Test_12          93.0
# Name: 0, dtype: float64

# %%
#multiple rows
df.iloc[[1,4,6]]
# Out:
#    Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  \
# 1       22001      79    71.0      81    72.0      73      68      59      69
# 4       22004      99    95.0      96    93.0      97      89      92      98
# 6       22006      47    50.0      47    57.0      62      64      71      75
#
#    Test_9  Test_10  Test_11  Test_12
# 1      59       60       61       67
# 4      91       98       95       88
# 6      85       87       85       89

# %%
df.iloc[1:4]
# Out:
#    Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  \
# 1       22001      79    71.0      81    72.0      73      68      59      69
# 2       22002      66    65.0      70    74.0      78      86      87      96
# 3       22003      60     NaN      54     NaN      54      57      64      62
#
#    Test_9  Test_10  Test_11  Test_12
# 1      59       60       61       67
# 2      88       82       90       86
# 3      72       63       72       76

# %%
#selecting rows and cols using loc and iloc
#the first argument is rows and second one is column
#df.iloc[[1,4,6],0]
df.iloc[[1,4,6],[0,4]]
# Out:
#    Student_ID  Test_4
# 1       22001    72.0
# 4       22004    93.0
# 6       22006    57.0

# %%
df.iloc[1:4,1:4]
#for slicing no inner brackets
# Out:
#    Test_1  Test_2  Test_3
# 1      79    71.0      81
# 2      66    65.0      70
# 3      60     NaN      54

# %%
df.head()
# Out:
#    Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  \
# 0       22000      78     NaN      91    91.0      88      98      94     100
# 1       22001      79    71.0      81    72.0      73      68      59      69
# 2       22002      66    65.0      70    74.0      78      86      87      96
# 3       22003      60     NaN      54     NaN      54      57      64      62
# 4       22004      99    95.0      96    93.0      97      89      92      98
#
#    Test_9  Test_10  Test_11  Test_12
# 0     100      100      100       93
# 1      59       60       61       67
# 2      88       82       90       86
# 3      72       63       72       76
# 4      91       98       95       88

# %%
df.loc[[1,3,4],['Test_2']]
# Out:
#    Test_2
# 1    71.0
# 3     NaN
# 4    95.0

# %%
#loc:searching by label:here label of a row  is index only.
df.loc[[1,4,6],'Test_1']
# Out:
# 1    79
# 4    99
# 6    47
# Name: Test_1, dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df_1 = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df_1)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df_1.loc[["day1","day2"]]
# Out:
#       calories  duration
# day1       420        50
# day2       380        40

# %%
#creating data frames naturally from multiple lists
import pandas as pd
new_df=pd.DataFrame(columns=["a","b","c"])
new_df["a"]=pd.Series([1,2,3,4,5,6])
new_df["b"]=pd.Series(["ramu","gopi","krishna"])
new_df["c"]=pd.Series([10,20,30,40,50,60])
print(new_df)
# Out:
#    a        b   c
# 0  1     ramu  10
# 1  2     gopi  20
# 2  3  krishna  30
# 3  4      NaN  40
# 4  5      NaN  50
# 5  6      NaN  60

# %%
#new_df
# Out:
#    a        b   c
# 0  1     ramu  10
# 1  2     gopi  20
# 2  3  krishna  30
# 3  4      NaN  40
# 4  5      NaN  50
# 5  6      NaN  60

# %%
#add/remove rows and columns
df.drop(columns=['Test_1'])
#df.drop(columns=['Test_1','Test_4'])
# Out:
#     Student_ID  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  \
# 0        22000     NaN      91    91.0      88      98      94     100
# 1        22001    71.0      81    72.0      73      68      59      69
# 2        22002    65.0      70    74.0      78      86      87      96
# 3        22003     NaN      54     NaN      54      57      64      62
# 4        22004    95.0      96    93.0      97      89      92      98
# 5        22005    36.0      35    28.0      35      36      27      26
# 6        22006    50.0      47    57.0      62      64      71      75
# 7        22007    74.0      70    68.0      58      59      56      56
# 8        22008    64.0      58    57.0      53      51      47      45
# 9        22009    81.0      73    74.0      71      63      53      45
# 10       22010    34.0      37    33.0      31      35      39      38
# 11       22011    84.0      78    74.0      76      80      80      73
# ...

# %%
new_df.isna().sum()
# Out:
# a    0
# b    3
# c    0
# dtype: int64

# %%
new_df.isna().sum()/len(new_df)*100
# Out:
# a     0.0
# b    50.0
# c     0.0
# dtype: float64
